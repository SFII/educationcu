# %% [markdown]
# ## 09/07/15 1.0 - Limited number of comment boxes and responces:
#
# ### Markdown ordered list not working but theres 13 questions
#
#
# 1. How much time did it take to keep up with the course outside of class : A small amount; A large amount; Depends on the week;
#
#     * Asking how much time a course takes up per week is too arbitrary since workloads fluctuate
#     * Asking students a more vague question could lead to more interesting data
#     * This question could activate another question like "What about during exam weeks" ect...
#     * This question could include an additional comments box
#
#
# 2. Personal experience in this field of study : No experience; Some experience; Lots of experience;
#
#     * Important for comparing final grade with other survey fields
#
#
# 3. Personal interest in the material before taking the course : No interest; Some interest; Lots of interest;
#
#     * Important for comparing final grade with other survey fields
#
#
# 4. How long does it take for an instructor to lose your attention in a single lecture: 10min; 20min; 30min;
#
#     * Interesting question when comparted to other classes and professors of the same class
#     * Answers could be in five minute increments, less than or greater than 10/30 minutes ect...
#     * 25 minutes is the average time it takes to lose a humans attention in any one activity
#
#
# 5. Instructors avaliability :  No avaliability; Some avaliability; Lots of avaliability;
#
#     * Instructors that make time for students are typically well recieved
#
#
# 6. Would you want to work with this instructor in a professional setting : Yes; No;
#
#     * This is the question in place of asking if the professor was good at his job / made an genuine effort
#
#
# 7. Overall challenge of the course : Not very challenging; Somewhat challening; Very challenging
#
#     * Raw data collection after an interesting question
#     * Keeping answer options limited promotes critical thinking when answering
#
#
# 8. Did you need to read the book(s) to do well in this course? : Yes; No;
#
#     * The answer would not be indicative of the instructors ability but would be great to know before picking the class
#
#
#
# 9. Would you recommend the course to a friend? : Yes; No;
#
#     * Able to predict course ease/difficulty and instructor effectiveness when compared with other questions
#
#
# 10. Grade you think you got by the end of the course? : F-D; D-C; C-B; B-A;
#
#     * Shows curve or no curve when compared with next question
#
#
# 11. Grade you actually got : F-D; D-C; C-B; B-A;
#
#     * Raw data
#     * Leave blank if filled out prior to end of the course, remove field before a certain date
#
#
#
# 12. Comments on the instructor + overall rating : Rating out of 3 (Bad, Normal, Good)
#
#     * Raw data
#     * Comments
#
#
# 13. Comments on the course material + overall rating : Rating out of 3 (Bad, Normal, Good)
#
#     * Raw data
#     * Comments
#
#
# ## Notes:
#
# Have a small amount of important questions so people actually fill out the survey. Possibly word questions in a more thought provoking way so students recognize that their contributing exciting data.
#
# Have questions with a small number of options and word scales instead of number scales reduces vagueness in my opinion.
#
# When these questions are answered, more interesting data would be found if some question answers were compared to other question answers.
